# %%
# !pip install -U -q keras-nlp
# !pip install --upgrade keras
# !pip install kagglehub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.4/548.4 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 102.8 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Collecting keras
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.7 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# Successfully installed keras-3.5.0
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.2.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.8.30)

# %%
#use this code to login to kaggle if kaggle username and kaggle token are saved in your colab credentials.
import os
from google.colab import userdata
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')
os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')

# %%
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.0)
# Kaggle credentials successfully validated.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
import kagglehub

# Download latest version
path = kagglehub.model_download("metaresearch/llama-3.1/transformers/8b-instruct")
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.0)
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.0)
# Downloading 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/original/params.json...
# 100%|██████████| 199/199 [00:00<00:00, 152kB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/LICENSE...
# 100%|██████████| 7.45k/7.45k [00:00<00:00, 4.65MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/README.md...
#   0%|          | 0.00/43.0k [00:00<?, ?B/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/USE_POLICY.md...
# 100%|██████████| 4.58k/4.58k [00:00<00:00, 2.95MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/.gitattributes...
# 100%|██████████| 1.48k/1.48k [00:00<00:00, 873kB/s]
# 100%|██████████| 43.0k/43.0k [00:00<00:00, 977kB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/config.json...
#   0%|          | 0.00/855 [00:00<?, ?B/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/original/consolidated.00.pth...
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/original/tokenizer.model...
# 100%|██████████| 855/855 [00:00<00:00, 95.2kB/s]
#
#   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/generation_config.json...
# 100%|██████████| 184/184 [00:00<00:00, 202kB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/model-00002-of-00004.safetensors...
#   0%|          | 0.00/4.66G [00:00<?, ?B/s]
#
#   0%|          | 1.00M/15.0G [00:01<5:42:16, 782kB/s]
#  48%|████▊     | 1.00M/2.08M [00:01<00:01, 782kB/s]
#
#   0%|          | 2.00M/15.0G [00:01<2:57:06, 1.51MB/s]
# 100%|██████████| 2.08M/2.08M [00:01<00:00, 1.37MB/s]
#
#
#   0%|          | 3.00M/15.0G [00:01<1:51:15, 2.41MB/s]
#
#   0%|          | 4.00M/15.0G [00:01<1:17:24, 3.46MB/s]
#
#   0%|          | 6.00M/15.0G [00:01<45:04, 5.94MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/model-00004-of-00004.safetensors...
#   0%|          | 0.00/1.09G [00:00<?, ?B/s]
#
#   0%|          | 8.00M/15.0G [00:02<31:40, 8.44MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/model-00003-of-00004.safetensors...
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/model-00001-of-00004.safetensors...
#   0%|          | 0.00/4.58G [00:00<?, ?B/s]
#
#
#
#
#   0%|          | 0.00/4.63G [00:00<?, ?B/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/model.safetensors.index.json...
# 100%|██████████| 23.4k/23.4k [00:00<00:00, 2.76MB/s]
#
#
#
#   0%|          | 1.00M/4.66G [00:01<1:47:00, 779kB/s]
#
#   0%|          | 10.0M/15.0G [00:02<25:39, 10.4MB/s]
#
#   0%|          | 12.0M/15.0G [00:02<21:56, 12.2MB/s]
#
#
#   0%|          | 2.00M/4.66G [00:01<55:07, 1.51MB/s]
#
#   0%|          | 14.0M/15.0G [00:02<19:31, 13.7MB/s]
#
#
#   0%|          | 3.00M/4.66G [00:01<34:40, 2.40MB/s]
#
#   0%|          | 16.0M/15.0G [00:02<18:32, 14.4MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/special_tokens_map.json...
# 100%|██████████| 296/296 [00:00<00:00, 888kB/s]
#
#
#   0%|          | 18.0M/15.0G [00:02<17:04, 15.7MB/s]
#
#
#   0%|          | 5.00M/4.66G [00:01<18:50, 4.42MB/s]
#
#   0%|          | 20.0M/15.0G [00:02<17:03, 15.7MB/s]
#
#
#   0%|          | 7.00M/4.66G [00:01<12:20, 6.74MB/s]
#
#   0%|          | 22.0M/15.0G [00:02<15:47, 16.9MB/s]
#
#
#   0%|          | 9.00M/4.66G [00:02<09:32, 8.71MB/s]
#
#   0%|          | 24.0M/15.0G [00:03<16:22, 16.3MB/s]
#
#
#   0%|          | 11.0M/4.66G [00:02<07:34, 11.0MB/s]
#
#   0%|          | 26.0M/15.0G [00:03<15:41, 17.0MB/s]
#
#
#   0%|          | 13.0M/4.66G [00:02<06:52, 12.1MB/s]
#
#   0%|          | 28.0M/15.0G [00:03<16:28, 16.2MB/s]
#
#
#   0%|          | 15.0M/4.66G [00:02<06:04, 13.7MB/s]
#
#
#   0%|          | 17.0M/4.66G [00:02<05:34, 14.9MB/s]
#
#
#
#
#   0%|          | 1.00M/4.63G [00:01<1:46:47, 777kB/s]
#   0%|          | 1.00M/1.09G [00:01<25:29, 763kB/s]
#
#
#
#   0%|          | 1.00M/4.58G [00:01<1:46:23, 770kB/s]
#
#   0%|          | 30.0M/15.0G [00:03<18:58, 14.1MB/s]
#
#
#   0%|          | 19.0M/4.66G [00:02<05:13, 15.9MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/tokenizer.json...
#   0%|          | 0.00/8.66M [00:00<?, ?B/s]
#   0%|          | 2.00M/1.09G [00:01<12:59, 1.50MB/s]
#
#
#
#
#   0%|          | 2.00M/4.63G [00:01<55:03, 1.51MB/s]
#
#
#   0%|          | 21.0M/4.66G [00:02<05:15, 15.8MB/s]
#
#
#
#   0%|          | 2.00M/4.58G [00:01<54:43, 1.50MB/s]
#
#   0%|          | 33.0M/15.0G [00:03<18:23, 14.5MB/s]
#
#
#   0%|          | 23.0M/4.66G [00:02<05:00, 16.6MB/s]
#   0%|          | 3.00M/1.09G [00:01<08:10, 2.38MB/s]
#
#
#
#
#   0%|          | 3.00M/4.63G [00:01<34:28, 2.40MB/s]
#
#
#
#   0%|          | 3.00M/4.58G [00:01<34:17, 2.39MB/s]
#
#
#   1%|          | 25.0M/4.66G [00:03<04:52, 17.0MB/s]
#
#   0%|          | 37.0M/15.0G [00:03<16:39, 16.0MB/s]
#   0%|          | 5.00M/1.09G [00:01<04:25, 4.38MB/s]
#
#
#
#
#   0%|          | 5.00M/4.63G [00:01<18:43, 4.43MB/s]
#
#
#
#   0%|          | 5.00M/4.58G [00:01<18:42, 4.37MB/s]
#
#
#   1%|          | 27.0M/4.66G [00:03<04:57, 16.7MB/s]
#
#
#
#
#   0%|          | 7.00M/4.63G [00:01<12:12, 6.79MB/s]
#   1%|          | 7.00M/1.09G [00:02<02:53, 6.69MB/s]
#
#
#
#   0%|          | 7.00M/4.58G [00:02<12:11, 6.71MB/s]
#
#
#   1%|          | 29.0M/4.66G [00:03<04:43, 17.5MB/s]
#
#   0%|          | 41.0M/15.0G [00:04<15:53, 16.8MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/metaresearch/llama-3.1/transformers/8b-instruct/2/download/tokenizer_config.json...
# Streaming output truncated to the last 5000 lines.
#  59%|█████▊    | 8.78G/15.0G [09:38<07:52, 14.0MB/s]
#
#  59%|█████▊    | 8.79G/15.0G [09:39<08:07, 13.6MB/s]
#
#  59%|█████▉    | 8.79G/15.0G [09:39<08:21, 13.2MB/s]
#
#  59%|█████▉    | 8.79G/15.0G [09:39<06:47, 16.2MB/s]
#
#  59%|█████▉    | 8.79G/15.0G [09:39<07:38, 14.4MB/s]
#
#  59%|█████▉    | 8.80G/15.0G [09:39<07:57, 13.9MB/s]
#
#  59%|█████▉    | 8.80G/15.0G [09:40<08:14, 13.4MB/s]
#
#  59%|█████▉    | 8.80G/15.0G [09:40<06:51, 16.1MB/s]
#
#  59%|█████▉    | 8.81G/15.0G [09:40<07:33, 14.6MB/s]
#
#  59%|█████▉    | 8.81G/15.0G [09:40<07:52, 14.0MB/s]
#
#  59%|█████▉    | 8.81G/15.0G [09:40<08:11, 13.4MB/s]
#
#  59%|█████▉    | 8.81G/15.0G [09:40<06:49, 16.1MB/s]
#
#  59%|█████▉    | 8.82G/15.0G [09:41<07:31, 14.6MB/s]
#
#  59%|█████▉    | 8.82G/15.0G [09:41<08:34, 12.8MB/s]
#
#  59%|█████▉    | 8.82G/15.0G [09:41<07:01, 15.6MB/s]
#
#  59%|█████▉    | 8.82G/15.0G [09:41<07:37, 14.4MB/s]
#
#  59%|█████▉    | 8.83G/15.0G [09:41<07:56, 13.8MB/s]
#
#  59%|█████▉    | 8.83G/15.0G [09:42<08:13, 13.3MB/s]
#
#  59%|█████▉    | 8.83G/15.0G [09:42<06:53, 15.9MB/s]
#
#  59%|█████▉    | 8.83G/15.0G [09:42<07:29, 14.6MB/s]
#
#  59%|█████▉    | 8.84G/15.0G [09:42<07:50, 14.0MB/s]
#
#  59%|█████▉    | 8.84G/15.0G [09:42<08:08, 13.4MB/s]
#
#  59%|█████▉    | 8.84G/15.0G [09:43<07:42, 14.2MB/s]
#
#  59%|█████▉    | 8.84G/15.0G [09:43<08:06, 13.5MB/s]
#
#  59%|█████▉    | 8.85G/15.0G [09:43<09:06, 12.0MB/s]
#
#  59%|█████▉    | 8.85G/15.0G [09:43<08:17, 13.2MB/s]
#
#  59%|█████▉    | 8.85G/15.0G [09:43<08:12, 13.3MB/s]
#
#  59%|█████▉    | 8.85G/15.0G [09:43<07:37, 14.3MB/s]
#
#  59%|█████▉    | 8.85G/15.0G [09:44<07:42, 14.2MB/s]
#
#  59%|█████▉    | 8.86G/15.0G [09:44<07:15, 15.1MB/s]
#
#  59%|█████▉    | 8.86G/15.0G [09:44<07:26, 14.7MB/s]
#
#  59%|█████▉    | 8.86G/15.0G [09:44<07:03, 15.5MB/s]
#  99%|█████████▉| 14.9G/15.0G [17:04<00:07, 14.9MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:04<00:06, 15.3MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:05<00:08, 12.2MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:05<00:08, 12.4MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:05<00:08, 11.3MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:05<00:06, 14.6MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:05<00:06, 14.0MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:06<00:06, 13.6MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:06<00:06, 13.3MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:06<00:05, 16.0MB/s]
#
#  99%|█████████▉| 14.9G/15.0G [17:06<00:05, 15.1MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:06<00:05, 14.3MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:07<00:05, 13.8MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:07<00:04, 16.3MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:07<00:04, 15.3MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:07<00:05, 13.2MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:07<00:04, 16.0MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:07<00:04, 15.1MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:08<00:04, 14.1MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:08<00:04, 13.8MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:08<00:03, 16.4MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:08<00:03, 15.2MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:08<00:03, 14.4MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:09<00:03, 14.0MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:09<00:02, 16.5MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:09<00:02, 15.3MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:09<00:02, 14.4MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:09<00:02, 14.0MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:09<00:01, 16.5MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:10<00:01, 15.3MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:10<00:02, 12.8MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:10<00:01, 13.8MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:10<00:01, 13.5MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:11<00:00, 14.3MB/s]
#
# 100%|█████████▉| 14.9G/15.0G [17:11<00:00, 14.5MB/s]
#
# 100%|█████████▉| 15.0G/15.0G [17:11<00:00, 12.7MB/s]
#
# 100%|█████████▉| 15.0G/15.0G [17:11<00:00, 13.7MB/s]
#
# 100%|██████████| 15.0G/15.0G [17:12<00:00, 15.6MB/s]
# Path to model files: /root/.cache/kagglehub/models/metaresearch/llama-3.1/transformers/8b-instruct/2

# %%
print("Path to model files:", path)
# Out:
# Path to model files: /root/.cache/kagglehub/models/metaresearch/llama-3.1/transformers/8b-instruct/2

# %%
# %%capture
# %pip install -U transformers accelerate

# %%
from time import time
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch
from IPython.display import display, Markdown

# %%
model_id = "/root/.cache/kagglehub/models/metaresearch/llama-3.1/transformers/8b-instruct/2"

tokenizer = AutoTokenizer.from_pretrained(model_id)

model = AutoModelForCausalLM.from_pretrained(
        model_id,
        return_dict=True,
        low_cpu_mem_usage=True,
        torch_dtype=torch.float16,
        device_map="auto",
        trust_remote_code=True,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
llama31_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.float16,
    device_map="auto",
)

# %%
def query_model(
        system_message,
        user_message,
        temperature=0.7,
        max_length=1024
        ):
    start_time = time()
    user_message = "Question: " + user_message + " Answer:"
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message},
        ]
    prompt = llama31_pipeline.tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
        )
    terminators = [
        llama31_pipeline.tokenizer.eos_token_id,
        llama31_pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
    ]
    sequences = llama31_pipeline(
        prompt,
        do_sample=True,
        top_p=0.9,
        temperature=temperature,
        num_return_sequences=1,
        eos_token_id=terminators,
        max_new_tokens=max_length,
        return_full_text=False,
        pad_token_id=terminators[0]
    )
    #answer = f"{sequences[0]['generated_text'][len(prompt):]}\n"
    answer = sequences[0]['generated_text']
    end_time = time()
    ttime = f"Total time: {round(end_time-start_time, 2)} sec."

    return user_message + " " + answer  + " " +  ttime


system_message = """
You are an AI assistant designed to answer simple questions.
Please restrict your answer to the exact question asked.
"""

# %%
def colorize_text(text):
    for word, color in zip(["Reasoning", "Question", "Answer", "Total time"], ["blue", "red", "green", "magenta"]):
        text = text.replace(f"{word}:", f"\n\n**<font color='{color}'>{word}:</font>**")
    return text

# %%
t1 = time()
response = query_model(
    system_message,
    user_message="What is the surface temperature of the Moon?",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(f"{response}")))
# Out:
# **<font color='red'>Question:</font>** What is the surface temperature of the Moon?
#
# **<font color='green'>Answer:</font>** The surface temperature of the Moon varies greatly between day and night. During the lunar day, which lasts about 29.5 Earth days, the surface temperature can reach as high as 127°C (261°F) in the direct sunlight.
#
# In the lunar night, the temperature can drop to as low as -173°C (-279°F) in the permanently shadowed craters near the lunar poles.
#
# **<font color='magenta'>Total time:</font>** 7.28 sec.

# %%
response = query_model(
    system_message,
    user_message="What is the surface of France?",
    temperature=0.1,
    max_length=128)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** What is the surface of France?
#
# **<font color='green'>Answer:</font>** The surface of France is approximately 643,801 square kilometers.
#
# **<font color='magenta'>Total time:</font>** 0.93 sec.

# %%
response = query_model(
    system_message,
    user_message="When was the 30 years war?",
    temperature=0.1,
    max_length=128)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** When was the 30 years war?
#
# **<font color='green'>Answer:</font>** The 30 Years War was a complex conflict that occurred from 1618 to 1648.
#
# **<font color='magenta'>Total time:</font>** 1.39 sec.

# %%
response = query_model(
    system_message,
    user_message="What is graphe paranomon?",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** What is graphe paranomon?
#
# **<font color='green'>Answer:</font>** Graphe paranomon is a term used in ancient Greek law. It refers to a type of impeachment or indictment in ancient Athens, where the charge was that the defendant had proposed a law that was "against the graphe" or "against the nomos" (the law or custom).
#
# **<font color='magenta'>Total time:</font>** 3.91 sec.

# %%
response = query_model(
    system_message,
    user_message="Who was the next shogun after Tokugawa Ieyasu?",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Who was the next shogun after Tokugawa Ieyasu?
#
# **<font color='green'>Answer:</font>** The next shogun after Tokugawa Ieyasu was Tokugawa Hidetada.
#
# **<font color='magenta'>Total time:</font>** 1.46 sec.

# %%
response = query_model(
    system_message,
    user_message="What was the name of the Chinese dinasty during 1st century B.C.?",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** What was the name of the Chinese dinasty during 1st century B.C.?
#
# **<font color='green'>Answer:</font>** The Han Dynasty.
#
# **<font color='magenta'>Total time:</font>** 0.35 sec.

# %%
response = query_model(
    system_message,
    user_message="Who was the first American president?",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Who was the first American president?
#
# **<font color='green'>Answer:</font>** George Washington.
#
# **<font color='magenta'>Total time:</font>** 0.28 sec.

# %%
response = query_model(
    system_message,
    user_message="When took place the Civil War in United States of America?",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** When took place the Civil War in United States of America?
#
# **<font color='green'>Answer:</font>** The American Civil War took place from 1861 to 1865.
#
# **<font color='magenta'>Total time:</font>** 1.06 sec.

# %%
system_message = """
You are an AI assistant designed to write poetry.
Please answer with a haiku format (17 words poems).
Question: {question}
Answer:
"""
response = query_model(
    system_message,
    user_message="Please write a poem about Boris Becker wins in tennis",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a poem about Boris Becker wins in tennis
#
# **<font color='green'>Answer:</font>** Racket's mighty swing
# Golden ace, his victory
# Becker's triumphant cry
#
# **<font color='magenta'>Total time:</font>** 1.25 sec.

# %%
response = query_model(
    system_message,
    user_message="Please write a poem about Shakespeare being lame at playing poker",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a poem about Shakespeare being lame at playing poker
#
# **<font color='green'>Answer:</font>** Bard's cards in disarray
# Shakespeare's bets are reckless fate
# Lame at poker's game
#
# **<font color='magenta'>Total time:</font>** 1.51 sec.

# %%
system_message = """
You are an AI assistant designed to write poetry.
Please answer with a short poem, with rime, in the style of Shakespeare's poems.
Question: {question}
Answer:
"""
response = query_model(
    system_message,
    user_message="Please write a poem about Nadia Comaneci winning Montreal Olympiad",
    temperature=0.1,
    max_length=512)
display(Markdown(colorize_text(response)))
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# **<font color='red'>Question:</font>** Please write a poem about Nadia Comaneci winning Montreal Olympiad
#
# **<font color='green'>Answer:</font>** In Montreal's hallowed halls of fame,
# A young Nadia shone with Olympic flame,
# Her gymnastics skills, a wondrous sight,
# A score of ten, a feat most bright.
#
# The crowd held breath, in awe and delight,
# As she performed, with movements so light,
# Her routines, a symphony of art,
# A perfect score, a maiden heart.
#
# The judges' marks, a unanimous decree,
# Ten points for Nadia, a history to see,
# The first to achieve, this feat so grand,
# A moment's magic, in this Olympic land.
#
# Her name etched, in the annals of time,
# A legend born, in this Montreal chime,
# Nadia Comaneci, a name so bold,
# A gymnast's glory, forever to hold.
#
# **<font color='magenta'>Total time:</font>** 10.42 sec.

# %%
system_message = """
You are an AI assistant designed to write simple Python code.
Please answer with the listing of the Python code.
Question: {question}
Answer:
"""
response = query_model(
    system_message,
    user_message="Please write a function in Python to calculate the area of a circle of radius r",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a function in Python to calculate the area of a circle of radius r
#
# **<font color='green'>Answer:</font>** ```python
# import math
#
# def calculate_circle_area(r):
#     """
#     Calculate the area of a circle given its radius.
#
#     Args:
#         r (float): The radius of the circle.
#
#     Returns:
#         float: The area of the circle.
#     """
#     if r < 0:
#         raise ValueError("Radius cannot be negative")
#     return math.pi * (r ** 2)
#
# # Example usage:
# radius = 5
# area = calculate_circle_area(radius)
# print(f"The area of the circle with radius {radius} is {area:.2f}")
# ```
#
# **<font color='magenta'>Total time:</font>** 7.64 sec.

# %%
response = query_model(
    system_message,
    user_message="Please write a function in Python to order a list",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a function in Python to order a list
#
# **<font color='green'>Answer:</font>** ```python
# def order_list(input_list):
#     """
#     This function takes a list of elements as input and returns the list in sorted order.
#
#     Args:
#         input_list (list): A list of elements to be sorted.
#
#     Returns:
#         list: A sorted list of elements.
#     """
#     return sorted(input_list)
#
# # Example usage:
# numbers = [64, 34, 25, 12, 22, 11, 90]
# print("Original list:", numbers)
# print("Sorted list:", order_list(numbers))
# ```
#
# This function uses the built-in `sorted()` function in Python, which returns a new sorted list from the elements of any sequence. The original list remains unchanged.
#
# **<font color='magenta'>Total time:</font>** 9.51 sec.

# %%
response = query_model(
    system_message,
    user_message="""Please write a class in Python
                        to model a phone book (storing name, surname, address, phone)
                        with add, delete, order by name, search operations.
                        The class should store a list of contacts, each
                        with name, surname, address, phone information stored.
                        """,
    temperature=0.1,
    max_length=1024)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a class in Python
#                         to model a phone book (storing name, surname, address, phone)
#                         with add, delete, order by name, search operations.
#                         The class should store a list of contacts, each
#                         with name, surname, address, phone information stored.
#
#
# **<font color='green'>Answer:</font>** ```python
# class Contact:
#     def __init__(self, name, surname, address, phone):
#         self.name = name
#         self.surname = surname
#         self.address = address
#         self.phone = phone
#
#     def __str__(self):
#         return f"{self.name} {self.surname}, {self.address}, {self.phone}"
#
#
# class PhoneBook:
#     def __init__(self):
#         self.contacts = []
#
#     def add_contact(self, name, surname, address, phone):
#         new_contact = Contact(name, surname, address, phone)
#         self.contacts.append(new_contact)
#         print(f"Contact added: {new_contact}")
#
#     def delete_contact(self, name, surname):
#         for contact in self.contacts:
#             if contact.name == name and contact.surname == surname:
#                 self.contacts.remove(contact)
#                 print(f"Contact deleted: {name} {surname}")
#                 return
#         print(f"No contact found for {name} {surname}")
#
#     def order_by_name(self):
#         self.contacts.sort(key=lambda x: (x.name, x.surname))
#         print("Contacts ordered by name:")
#         for contact in self.contacts:
#             print(contact)
#
#     def search_contact(self, name, surname):
#         for contact in self.contacts:
#             if contact.name == name and contact.surname == surname:
#                 print(f"Contact found: {contact}")
#                 return
#         print(f"No contact found for {name} {surname}")
#
#
# # Example usage:
# phone_book = PhoneBook()
#
# while True:
#     print("\nOptions:")
#     print("1. Add contact")
#     print("2. Delete contact")
#     print("3. Order contacts by name")
#     print("4. Search contact")
#     print("5. Exit")
#
#     choice = input("Choose an option: ")
#
#     if choice == "1":
#         name = input("Enter name: ")
#         surname = input("Enter surname: ")
#         address = input("Enter address: ")
#         phone = input("Enter phone: ")
#         phone_book.add_contact(name, surname, address, phone)
#     elif choice == "2":
#         name = input("Enter name: ")
#         surname = input("Enter surname: ")
#         phone_book.delete_contact(name, surname)
#     elif choice == "3":
#         phone_book.order_by_name()
#     elif choice == "4":
#         name = input("Enter name: ")
#         surname = input("Enter surname: ")
#         phone_book.search_contact(name, surname)
#     elif choice == "5":
#         break
#     else:
#         print("Invalid option")
# ```
#
# This code defines two classes: `Contact` and `PhoneBook`. The `Contact` class represents a single contact with attributes for name, surname, address, and phone number. The `PhoneBook` class represents a collection of contacts and provides methods to add, delete, order, and search contacts. The example usage at the end demonstrates how to use these classes in a simple command-line interface.
#
# **<font color='magenta'>Total time:</font>** 39.97 sec.

# %%
response = query_model(
    system_message,
    user_message="""Please write a small Python module that creates a REST API service
                        with two endpoints:
                        * get_status (GET)
                        * prediction (POST)
                        The prediction endpoint receives the payload, extract three fields: city, street and number
                        and returns a field called price_estimate

                        """,
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a small Python module that creates a REST API service
#                         with two endpoints:
#                         * get_status (GET)
#                         * prediction (POST)
#                         The prediction endpoint receives the payload, extract three fields: city, street and number
#                         and returns a field called price_estimate
#
#
#
# **<font color='green'>Answer:</font>** ```python
# # Import required libraries
# from flask import Flask, request, jsonify
# from flask_cors import CORS
#
# # Create a new Flask application
# app = Flask(__name__)
# CORS(app)
#
# # Sample data for demonstration purposes
# data = {
#     "New York": {"street": "Main St", "number": 123, "price_estimate": 1000},
#     "Los Angeles": {"street": "Sunset Blvd", "number": 456, "price_estimate": 800},
#     "Chicago": {"street": "Michigan Ave", "number": 789, "price_estimate": 1200}
# }
#
# # Define the get_status endpoint
# @app.route('/status', methods=['GET'])
# def get_status():
#     """Return a message indicating the API is up and running."""
#     return jsonify({"message": "API is up and running"})
#
# # Define the prediction endpoint
# @app.route('/predict', methods=['POST'])
# def prediction():
#     """Make a prediction based on the provided city, street, and number."""
#     try:
#         # Get the payload from the request
#         payload = request.json
#         # Extract the required fields
#         city = payload.get('city')
#         street = payload.get('street')
#         number = payload.get
#
# **<font color='magenta'>Total time:</font>** 16.78 sec.

# %%
system_message = """
You are an AI assistant designed to write simple C++ code.
Please answer with the listing of the C++ code.
Question: {question}
Answer:
"""
response = query_model(
    system_message,
    user_message="Please write a function in C++ to calculate the area of a circle of radius r",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a function in C++ to calculate the area of a circle of radius r
#
# **<font color='green'>Answer:</font>** ```cpp
# #include <iostream>
# #include <cmath>
#
# double calculateCircleArea(double r) {
#     // Calculate the area of a circle using the formula πr^2
#     double area = M_PI * pow(r, 2);
#     return area;
# }
#
# int main() {
#     double radius;
#     std::cout << "Enter the radius of the circle: ";
#     std::cin >> radius;
#     double area = calculateCircleArea(radius);
#     std::cout << "The area of the circle is: " << area << std::endl;
#     return 0;
# }
# ```
#
# This C++ code defines a function `calculateCircleArea` that calculates the area of a circle given its radius. The `main` function asks the user to input the radius, calls the `calculateCircleArea` function, and prints the result. The `M_PI` constant is used to represent the value of pi.
#
# **<font color='magenta'>Total time:</font>** 12.23 sec.

# %%
system_message = """
You are an AI assistant designed to write simple C++ code.
Please answer with the listing of the C++ code.
Question: {question}
Answer:
"""
response = query_model(
    system_message,
    user_message="Please write a function in C++ to calculate the volume of a cylinder with radius r and height h",
    temperature=0.1,
    max_length=512)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a function in C++ to calculate the volume of a cylinder with radius r and height h
#
# **<font color='green'>Answer:</font>** ```cpp
# #include <iostream>
#
# /**
#  * Calculates the volume of a cylinder with radius r and height h.
#  *
#  * @param r The radius of the cylinder.
#  * @param h The height of the cylinder.
#  * @return The volume of the cylinder.
#  */
# double calculateCylinderVolume(double r, double h) {
#     return 3.14159 * r * r * h;
# }
#
# int main() {
#     double radius = 5.0;
#     double height = 10.0;
#     double volume = calculateCylinderVolume(radius, height);
#     std::cout << "The volume of the cylinder is: " << volume << std::endl;
#     return 0;
# }
# ```
#
# This code defines a function `calculateCylinderVolume` that takes the radius `r` and height `h` as parameters and returns the volume of the cylinder. The `main` function demonstrates how to use this function to calculate the volume of a cylinder with a radius of 5.0 and a height of 10.0.
#
# **<font color='magenta'>Total time:</font>** 13.87 sec.

# %%
response = query_model(
    system_message,
    user_message="Please write a function in C++ to order a list",
    temperature=0.1,
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** Please write a function in C++ to order a list
#
# **<font color='green'>Answer:</font>** ```cpp
# #include <iostream>
# #include <vector>
# #include <algorithm>
#
# // Function to order a list
# std::vector<int> orderList(std::vector<int> list) {
#     // Sort the list in ascending order
#     std::sort(list.begin(), list.end());
#     return list;
# }
#
# int main() {
#     // Example usage
#     std::vector<int> numbers = {64, 34, 25, 12, 22, 11, 90};
#     std::vector<int> orderedNumbers = orderList(numbers);
#
#     // Print the ordered list
#     std::cout << "Ordered list: ";
#     for (int num : orderedNumbers) {
#         std::cout << num << " ";
#     }
#     std::cout << std::endl;
#
#     return 0;
# }
# ```
#
# This C++ code defines a function `orderList` that takes a vector of integers as input, sorts it in ascending order using the `std::sort` function from the `<algorithm>` library, and returns the sorted vector. The `main` function demonstrates how to use this function with an example list of numbers.
#
# **<font color='magenta'>Total time:</font>** 15.16 sec.

# %%
system_message = """
You are an AI assistant designed to answer questions with parameters.
Return the answer formated nicely, for example with bullet points.
"""
user_message = """
What are the {adjective} {number} {items} from {place}?
"""
response = query_model(
    system_message,
    user_message.format(
    adjective="best",
    number="3",
    items="food",
    place="France"
    ),
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the best 3 food from France?
#
#
# **<font color='green'>Answer:</font>** France, known for its rich culinary culture, offers a wide variety of delicious dishes. Here are three of the most popular and iconic French foods:
#
# * **Coq au Vin**: A classic French dish made with braised chicken cooked in red wine, mushrooms, onions, and bacon. The slow-cooked chicken is tender and flavorful, typically served with boiled potatoes and a side of steamed vegetables.
# * **Ratatouille**: A vegetable stew originating from Provence, ratatouille is a colorful and aromatic dish made with eggplant, zucchini, bell peppers, tomatoes, and garlic. It's often served as a side dish or used as a topping for bread or pasta.
# * **Escargots**: Snails cooked in garlic butter, typically served as an appetizer. The dish consists of snails that are first cleaned and then cooked in a mixture of garlic, parsley, and butter, often served with crusty bread for dipping in the flavorful sauce.
#
# These three dishes showcase the diversity and richness of French cuisine, highlighting the country's emphasis on fresh ingredients, bold flavors, and rich culinary traditions.
#
# **<font color='magenta'>Total time:</font>** 14.73 sec.

# %%
response = query_model(
    system_message,
    user_message.format(
    adjective="best",
    number="five",
    items="attractions",
    place="Italy"
    ),
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the best five attractions from Italy?
#
#
# **<font color='green'>Answer:</font>** Italy, a country known for its rich history, art, architecture, and delicious cuisine. Here are five of the best attractions Italy has to offer:
#
# * **The Colosseum (Rome)**: This ancient amphitheater is one of Rome's most iconic landmarks and a testament to the city's rich history. Built in the 1st century AD, it could hold up to 50,000 spectators and hosted gladiator battles, animal hunts, and public executions.
# * **The Leaning Tower of Pisa (Pisa)**: This famous tower is known for its unintended tilt, caused by the soft ground it was built on. Visitors can climb to the top for stunning views of the surrounding city and take a fun photo in front of the tower's unique design.
# * **The Grand Canal (Venice)**: This serene waterway is the lifeblood of Venice, a city built on water. Take a romantic gondola ride or stroll along the Riva degli Schiavoni to admire the stunning architecture and picturesque canals.
# * **The Uffizi Gallery (Florence)**: This world-renowned museum houses some of the most famous artworks in history, including Botticelli's "The Birth of Venus" and Leonardo da Vinci's
#
# **<font color='magenta'>Total time:</font>** 16.7 sec.

# %%
response = query_model(
    system_message,
    user_message.format(
    adjective="most affordable",
    number="two",
    items="places to retire",
    place="Spain"
    ),
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the most affordable two places to retire from Spain?
#
#
# **<font color='green'>Answer:</font>** Based on various sources and cost of living indexes, here are two affordable places to retire from Spain:
#
# *   **La Victoria de Acentejo, Tenerife, Canary Islands:**
#     *   Cost of living index: 72.27 (lower than the Spanish average)
#     *   Rent: 400-600 euros per month for a one-bedroom apartment
#     *   Average temperature: 22°C (72°F)
#     *   Access to beaches, mountains, and a vibrant cultural scene
#     *   Good healthcare and transportation options
# *   **Gandía, Valencia:**
#     *   Cost of living index: 75.42 (lower than the Spanish average)
#     *   Rent: 350-550 euros per month for a one-bedroom apartment
#     *   Average temperature: 17°C (63°F)
#     *   Beautiful beaches, historic center, and a lively nightlife
#     *   Good transportation links to Valencia city and the surrounding area
#
# These places offer a great balance of affordability, climate, and quality of life, making them ideal for retirees. However, keep in mind that prices may vary depending on the specific location, time of year, and other factors.
#
# It's always a good idea to research thoroughly and visit
#
# **<font color='magenta'>Total time:</font>** 16.73 sec.

# %%
response = query_model(
    system_message,
    user_message.format(
    adjective="Less known but great",
    number="4",
    items="places to stay",
    place="Romania"
    ),
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the Less known but great 4 places to stay from Romania?
#
#
# **<font color='green'>Answer:</font>** Here are 4 lesser-known but great places to stay in Romania:
#
# *   **Sighisoara Medieval Citadel**: Located in the heart of Transylvania, Sighisoara is a charming medieval town with a well-preserved citadel and colorful buildings. It's a UNESCO World Heritage Site and a great place to experience the country's rich history and culture.
#
# *   **Maramures County**: Located in the northeastern part of the country, Maramures County is a hidden gem that offers stunning natural beauty, traditional villages, and a unique cultural heritage. Visitors can explore the region's picturesque villages, visit ancient monasteries, and enjoy the local cuisine.
#
# *   **Orheiul Vechi Monastery**: Located in the Moldova region, Orheiul Vechi Monastery is a stunning rock monastery carved into the side of a cliff. The monastery dates back to the 13th century and features intricate stone carvings, beautiful frescoes, and a peaceful atmosphere.
#
# *   **Bran Castle (also known as Dracula's Castle)**: Located near Bran, this 14th-century castle is often mistakenly associated with the legend of Dracula. While it's a popular tourist destination, it's worth visiting for its stunning architecture, beautiful
#
# **<font color='magenta'>Total time:</font>** 16.73 sec.

# %%
response = query_model(
    system_message,
    user_message.format(
    adjective="best",
    number="3",
    items="commedies",
    place="Shakespeare entire creation"
    ),
    max_length=256)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the best 3 commedies from Shakespeare entire creation?
#
#
# **<font color='green'>Answer:</font>** Choosing the "best" comedies from Shakespeare's works can be subjective, but here are three of the most popular and highly-regarded comedies:
#
# * **A Midsummer Night's Dream**:
#     - A lighthearted and enchanting play that explores love, magic, and the power of imagination.
#     - Features a talented cast of characters, including the mischievous Puck, the lovesick Helena, and the bumbling Bottom.
#     - Includes some of Shakespeare's most beautiful and memorable language, such as the famous "What fools these mortals be" speech.
# * **Twelfth Night**:
#     - A witty and engaging comedy that explores themes of love, identity, and social class.
#     - Features a strong and clever heroine in Viola, who disguises herself as a man to serve the lovesick Orsino.
#     - Includes some of Shakespeare's most clever wordplay and comedic misunderstandings, such as the infamous "I am not what I am" speech.
# * **As You Like It**:
#     - A charming and pastoral comedy that explores themes of love, family, and identity.
#     - Features a strong and independent heroine in Rosalind, who disguises herself as a man to navigate the complexities of love and
#
# **<font color='magenta'>Total time:</font>** 16.71 sec.

# %%
response = query_model(
    system_message,
    user_message.format(
    adjective="most important",
    number="5",
    items="battles",
    place="WW2"
    ),
    max_length=512)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the most important 5 battles from WW2?
#
#
# **<font color='green'>Answer:</font>** Here are the top 5 most significant battles of World War II:
#
# *   **Battle of Stalingrad (August 1942 - February 1943)**
#     - Fought between the German Army and the Soviet Red Army
#     - Lasted for 5 months, resulting in a decisive Soviet victory
#     - Considered a turning point on the Eastern Front, marking the beginning of the end of German advances in the Soviet Union
#
# *   **Battle of Midway (June 1942)**
#     - Fought between the United States Navy and the Imperial Japanese Navy
#     - Lasted for 4 days, resulting in a decisive American victory
#     - Prevented a potential Japanese invasion of Hawaii and halted their advance in the Pacific
#
# *   **Battle of El Alamein (October - November 1942)**
#     - Fought between British and Commonwealth forces and the Axis powers (Germany and Italy)
#     - Lasted for 12 days, resulting in a decisive British victory
#     - Marked a turning point in the North African Campaign, marking the beginning of the end of Axis control in North Africa
#
# *   **Battle of Normandy (June 1944)**
#     - Fought between the Allied forces (primarily American, British, and Canadian) and the German Army
#     - Lasted for several weeks, resulting in a decisive Allied victory
#     - Marked the beginning of the end of German control in Western Europe
#
# *   **Battle of Berlin (April - May 1945)**
#     - Fought between the Soviet Red Army and the German Army
#     - Lasted for several weeks, resulting in a decisive Soviet victory
#     - Marked the final defeat of Nazi Germany, leading to the end of World War II in Europe
#
# **<font color='magenta'>Total time:</font>** 23.94 sec.

# %%
response = query_model(
    system_message,
    user_message.format(
    adjective="most important",
    number="5",
    items="battles",
    place="WW2"
    ),
    max_length=512)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>**
# What are the most important 5 battles from WW2?
#
#
# **<font color='green'>Answer:</font>** Here are the top 5 most important battles of World War 2:
#
# *   **1. The Battle of Stalingrad (August 1942 - February 1943)**
#     *   Location: Stalingrad, Russia
#     *   Significance: This was a major turning point on the Eastern Front, marking the first significant defeat of the German army and a crucial victory for the Soviet Union. The battle lasted for 5 months and resulted in the loss of over 1.8 million soldiers.
# *   **2. The Battle of Midway (June 1942)**
#     *   Location: Midway Island, Pacific Ocean
#     *   Significance: This naval battle was a decisive victory for the United States, preventing a potential Japanese invasion of Hawaii and halting the Japanese advance in the Pacific.
# *   **3. The Battle of El Alamein (October-November 1942)**
#     *   Location: Egypt
#     *   Significance: This battle marked a major turning point in North Africa, as British forces led by General Bernard Montgomery defeated the German-Italian army, paving the way for the Allied invasion of Italy.
# *   **4. The Battle of Normandy (D-Day) (June 6, 1944)**
#     *   Location: Normandy, France
#     *   Significance: This was the largest seaborne invasion in history, with over 156,000 troops landing on five beaches in Nazi-occupied France. The successful landing marked the beginning of the end of Germany's control over Western Europe.
# *   **5. The Battle of Berlin (April-May 1945)**
#     *   Location: Berlin, Germany
#     *   Significance: The final battle of the war in Europe, marking the capture of Berlin and the eventual surrender of German forces. This battle led to the end of World War 2 in Europe.
#
# These battles were crucial in shaping the course of the war and ultimately led to the Allied victory.
#
# **<font color='magenta'>Total time:</font>** 27.01 sec.

# %%
system_message = """
You are a math professor, smart but cool.
Background: A train traveling from Bucharest to Ploiesti (60 km distance) has the speed of 60 km/h.
The train starts in Bucharest and travels until Ploiesti, once, only in this direction.
A swallow, flying with 90 km/h, fly from Ploiesti to the moving train.
When it reaches the train, the swallow flies back toward Ploiesti,
ahead of the train. At Ploiesti turns again back and continues to fly back and forth
(between the train approaching Ploiesti and Ploiesti) until the train reaches Ploiesti.
The swallow will fly continously all the time the train is traveling from Bucharest to Ploiesti.
Reasoning: Think step by step. Explain your reasoning.
Question: {question}
Answer:
"""
response = query_model(
    system_message,
    user_message="How many kilometers will travel totally the swallow?",
    temperature=0.1,
    max_length=512)
display(Markdown(colorize_text(response)))
# Out:
# **<font color='red'>Question:</font>** How many kilometers will travel totally the swallow?
#
# **<font color='green'>Answer:</font>** To solve this problem, let's break it down step by step.
#
# 1.  The train travels from Bucharest to Ploiesti at a speed of 60 km/h. The distance between Bucharest and Ploiesti is 60 km. So, the time it takes for the train to reach Ploiesti is:
#
# Time = Distance / Speed = 60 km / 60 km/h = 1 hour
#
# 2.  The swallow flies from Ploiesti to the train at a speed of 90 km/h. When it reaches the train, it flies back to Ploiesti at the same speed. Since the train is moving at 60 km/h, the relative speed of the swallow with respect to the train is 90 km/h - 60 km/h = 30 km/h.
#
# 3.  The distance between the train and Ploiesti is decreasing at a rate of 60 km/h (train's speed). When the swallow flies from Ploiesti to the train, it covers this decreasing distance. The time it takes for the swallow to fly from Ploiesti to the train is:
#
# Time = Distance / Relative Speed = (60 km) / (30 km/h) = 2 hours
#
# 4.  Since the swallow flies back and forth between the train and Ploiesti, it makes two trips for every hour the train travels. In the first hour, the train covers 60 km, and the swallow makes two trips, covering a distance of 2 * (60 km + 60 km) = 240 km.
#
# 5.  In the second hour, the train covers another 60 km, and the swallow makes two more trips, covering a distance of 2 * (60 km + 60 km) = 240 km. The total distance covered by the swallow in the first two hours is 240 km + 240 km = 480 km.
#
# 6.  Since the train takes 1 hour to reach Ploiesti, the swallow makes a total of 2 trips in the first hour and 2 trips in the second hour, for a total of 4 trips. The total distance covered by the swallow is 4 * (60 km + 60 km) = 480 km.
#
# However, this is not the correct answer. The swallow will make more trips in the last hour, when the train is approaching Ploiesti. In the last hour, the train covers 60 km, and the swallow makes
#
# **<font color='magenta'>Total time:</font>** 33.95 sec.
